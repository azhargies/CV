# %% [markdown]
# <a href="https://colab.research.google.com/github/azhargies/CV/blob/CV/12th_Jan_2023_reva_MCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns

# %%
data = pd.read_csv("/content/Celsius_to_Fahrenheit.csv")
data
# Out:
#     Celsius  Fahrenheit
# 0       -50       -58.0
# 1       -40       -40.0
# 2       -30       -22.0
# 3       -20        -4.0
# 4       -10        14.0
# 5        -9        15.8
# 6        -8        17.6
# 7        -7        19.4
# 8        -6        21.2
# 9        -5        23.0
# 10       -4        24.8
# 11       -3        26.6
# 12       -2        28.4
# 13       -1        30.2
# 14        0        32.0
# 15        1        33.8
# 16        2        35.6
# 17        3        37.4
# 18        4        39.2
# 19        5        41.0
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
data.shape
# Out:
# (30, 2)

# %%
X = data["Celsius"]
Y = data["Fahrenheit"]

# %%
#1. Build Sequential Model: input layer-shape, output layer - no. of classes
#2. Compilation: Optimizer, Loss, metrics
#3. Fit the model: xtrain, ytrain, epochs

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(1, input_shape=[1]))

model.compile(optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.5), loss = "mean_squared_error")

model.fit(X,Y, epochs = 1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 231ms/step - loss: 4739.7534
# Epoch 2/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 3458.0112
# Epoch 3/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 2440.6885
# Epoch 4/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1686.8040
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1186.4304
# Epoch 6/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 916.6655
# Epoch 7/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 838.2765
# Epoch 8/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 895.7355
# Epoch 9/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1023.6783
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1159.4628
# Epoch 11/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1256.1736
# Epoch 12/1000
# ...

# %%
temp = [40.0]

model.predict(temp)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# array([[104.000015]], dtype=float32)
