# %% [markdown]
# <a href="https://colab.research.google.com/github/azhargies/CV/blob/CV/9_jan_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("/content/Celsius_to_Fahrenheit.csv")

# %%
data.head()
# Out:
#    Celsius  Fahrenheit
# 0      -50       -58.0
# 1      -40       -40.0
# 2      -30       -22.0
# 3      -20        -4.0
# 4      -10        14.0

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(data["Celsius"], data["Fahrenheit"],test_size = 0.2, random_state=2)

# %%
xtrain.head()
# Out:
# 23     9
# 6     -8
# 3    -20
# 20     6
# 5     -9
# Name: Celsius, dtype: int64

# %%
from tensorflow import keras

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(units=1, input_shape=[1]))
model.summary()
model.compile(optimizer = "Adam", loss = "mean_squared_error", metrics = ["mean_squared_error"])
model.fit(data["Celsius"], data["Fahrenheit"],epochs = 100)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 0s 331ms/step - loss: 1048.2283 - mean_squared_error: 1048.2283
# Epoch 2/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1047.9087 - mean_squared_error: 1047.9087
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1047.5900 - mean_squared_error: 1047.5900
# Epoch 4/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1047.2723 - mean_squared_error: 1047.2723
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1046.9559 - mean_squared_error: 1046.9559
# Epoch 6/100
# ...

# %%
model.predict([255])
# Out:
# 1/1 [==============================] - 0s 40ms/step
# array([[450.4634]], dtype=float32)

# %%
model.intercept
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-af39353c43c9> in <module>
# ----> 1 model.intercept
#
# AttributeError: 'Sequential' object has no attribute 'intercept'

# %%
abalone_train = pd.read_csv(
    "https://storage.googleapis.com/download.tensorflow.org/data/abalone_train.csv",
    names=["Length", "Diameter", "Height", "Whole weight", "Shucked weight",
           "Viscera weight", "Shell weight", "Age"])

abalone_train.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.435     0.335   0.110         0.334          0.1355          0.0775
# 1   0.585     0.450   0.125         0.874          0.3545          0.2075
# 2   0.655     0.510   0.160         1.092          0.3960          0.2825
# 3   0.545     0.425   0.125         0.768          0.2940          0.1495
# 4   0.545     0.420   0.130         0.879          0.3740          0.1695
#
#    Shell weight  Age
# 0        0.0965    7
# 1        0.2250    6
# 2        0.3700   14
# 3        0.2600   16
# 4        0.2300   13

# %%
abalone_features = abalone_train.copy()
abalone_features.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.435     0.335   0.110         0.334          0.1355          0.0775
# 1   0.585     0.450   0.125         0.874          0.3545          0.2075
# 2   0.655     0.510   0.160         1.092          0.3960          0.2825
# 3   0.545     0.425   0.125         0.768          0.2940          0.1495
# 4   0.545     0.420   0.130         0.879          0.3740          0.1695
#
#    Shell weight  Age
# 0        0.0965    7
# 1        0.2250    6
# 2        0.3700   14
# 3        0.2600   16
# 4        0.2300   13

# %%
abalone_features.pop('Age')
# Out:
# 0        7
# 1        6
# 2       14
# 3       16
# 4       13
#         ..
# 3315    15
# 3316    10
# 3317    11
# 3318    16
# 3319    19
# Name: Age, Length: 3320, dtype: int64

# %%
abalone_features.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.435     0.335   0.110         0.334          0.1355          0.0775
# 1   0.585     0.450   0.125         0.874          0.3545          0.2075
# 2   0.655     0.510   0.160         1.092          0.3960          0.2825
# 3   0.545     0.425   0.125         0.768          0.2940          0.1495
# 4   0.545     0.420   0.130         0.879          0.3740          0.1695
#
#    Shell weight
# 0        0.0965
# 1        0.2250
# 2        0.3700
# 3        0.2600
# 4        0.2300

# %%
abalone_features = np.array(abalone_features)
abalone_features
# Out:
# array([[0.435 , 0.335 , 0.11  , ..., 0.1355, 0.0775, 0.0965],
#        [0.585 , 0.45  , 0.125 , ..., 0.3545, 0.2075, 0.225 ],
#        [0.655 , 0.51  , 0.16  , ..., 0.396 , 0.2825, 0.37  ],
#        ...,
#        [0.53  , 0.42  , 0.13  , ..., 0.3745, 0.167 , 0.249 ],
#        [0.395 , 0.315 , 0.105 , ..., 0.1185, 0.091 , 0.1195],
#        [0.45  , 0.355 , 0.12  , ..., 0.1145, 0.0665, 0.16  ]])

# %%
abalone_features.shape
# Out:
# (3320, 7)

# %%
abalone_model = tf.keras.Sequential([
  keras.layers.Dense(units = 16, input_shape = (7,)),
  keras.layers.Dense(1)
])

abalone_model.compile(loss = tf.keras.losses.MeanSquaredError(),
                      optimizer = tf.keras.optimizers.Adam())

# %%
abalone_model.fit(abalone_features, abalone_labels, epochs=50)
# Out:
# Epoch 1/50
# 104/104 [==============================] - 1s 3ms/step - loss: 79.2762
# Epoch 2/50
# 104/104 [==============================] - 0s 2ms/step - loss: 34.3736
# Epoch 3/50
# 104/104 [==============================] - 0s 2ms/step - loss: 11.8203
# Epoch 4/50
# 104/104 [==============================] - 0s 3ms/step - loss: 8.4400
# Epoch 5/50
# 104/104 [==============================] - 0s 2ms/step - loss: 8.1727
# Epoch 6/50
# 104/104 [==============================] - 0s 2ms/step - loss: 8.0097
# Epoch 7/50
# 104/104 [==============================] - 0s 3ms/step - loss: 7.8583
# Epoch 8/50
# 104/104 [==============================] - 0s 2ms/step - loss: 7.7066
# Epoch 9/50
# 104/104 [==============================] - 0s 2ms/step - loss: 7.5711
# Epoch 10/50
# 104/104 [==============================] - 0s 2ms/step - loss: 7.4517
# Epoch 11/50
# 104/104 [==============================] - 0s 3ms/step - loss: 7.3450
# Epoch 12/50
# ...
